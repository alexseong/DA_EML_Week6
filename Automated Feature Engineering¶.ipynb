# %%
import pandas as pd
import numpy as np

# %%
import featuretools as ft

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
clients = pd.read_csv('./data/clients.csv', parse_dates = ['joined'])
loans = pd.read_csv('./data/loans.csv', parse_dates = ['loan_start', 'loan_end'])
payments = pd.read_csv('./data/payments.csv', parse_dates = ['payment_date'])

# %%
clients.head()
# Out:
#    client_id     joined  income  credit_score
# 0      46109 2002-04-16  172677           527
# 1      49545 2007-11-14  104564           770
# 2      41480 2013-03-11  122607           585
# 3      46180 2001-11-06   43851           562
# 4      25707 2006-10-06  211422           621

# %%
loans.sample(10)
# Out:
#      client_id loan_type  loan_amount  repaid  loan_id loan_start   loan_end  \
# 235      32961    credit        12553       1    11113 2001-09-08 2003-06-15
# 238      32961     other        13674       0    11932 2013-11-24 2016-08-08
# 265      44601      home         8635       1    10700 2004-03-08 2006-10-07
# 150      35089      home        10947       0    11793 2000-09-08 2003-01-14
# 365      26695     other         9323       1    10468 2002-10-22 2005-03-17
# 77       46180    credit         5362       0    10237 2013-01-07 2014-05-23
# 175      35214     other         4953       1    10908 2010-07-23 2012-05-02
# 243      32961    credit        10602       1    11427 2008-06-05 2009-12-19
# 140      35089      home         9175       1    11547 2003-04-02 2005-04-21
# 51       41480     other         4491       1    10511 2002-06-08 2004-08-09
#
#      rate
# 235  2.98
# 238  2.15
# 265  4.97
# 150  0.67
# 365  2.79
# 77   2.48
# 175  0.16
# 243  4.44
# 140  5.36
# 51   2.82

# %%
payments.sample(10)
# Out:
#       loan_id  payment_amount payment_date  missed
# 1877    10144            1400   2002-02-09       1
# 1159    10336            1791   2014-10-26       0
# 2679    10683            1019   2007-05-03       1
# 307     10888            2719   2004-06-10       0
# 1611    10763            1261   2007-11-09       0
# 2180    10681            1788   2009-01-29       1
# 1320    11968             848   2014-10-24       1
# 2902    11197            1659   2007-08-12       1
# 3246    10714            1057   2003-10-26       1
# 2232    10024             878   2006-01-11       1

# %%
clients['join_month'] = clients['joined'].dt.month
clients['log_income'] = np.log(clients['income'])
clients.head()
# Out:
#    client_id     joined  income  credit_score  join_month  log_income
# 0      46109 2002-04-16  172677           527           4   12.059178
# 1      49545 2007-11-14  104564           770          11   11.557555
# 2      41480 2013-03-11  122607           585           3   11.716739
# 3      46180 2001-11-06   43851           562          11   10.688553
# 4      25707 2006-10-06  211422           621          10   12.261611

# %%
stats = loans.groupby('client_id')['loan_amount'].agg(['mean', 'max', 'min'])
stats.columns = ['mean_loan_amount', 'max_loan_amount', 'min_loan_amount']
stats.head()
# Out:
#            mean_loan_amount  max_loan_amount  min_loan_amount
# client_id
# 25707           7963.950000            13913             1212
# 26326           7270.062500            13464             1164
# 26695           7824.722222            14865             2389
# 26945           7125.933333            14593              653
# 29841           9813.000000            14837             2778

# %%
clients.merge(stats, left_on = 'client_id', right_index=True, how = 'left').head(10)
# Out:
#    client_id     joined  income  credit_score  join_month  log_income  \
# 0      46109 2002-04-16  172677           527           4   12.059178
# 1      49545 2007-11-14  104564           770          11   11.557555
# 2      41480 2013-03-11  122607           585           3   11.716739
# 3      46180 2001-11-06   43851           562          11   10.688553
# 4      25707 2006-10-06  211422           621          10   12.261611
# 5      39505 2011-10-14  153873           610          10   11.943883
# 6      32726 2006-05-01  235705           730           5   12.370336
# 7      35089 2010-03-01  131176           771           3   11.784295
# 8      35214 2003-08-08   95849           696           8   11.470529
# 9      48177 2008-06-09  190632           769           6   12.158100
#
#    mean_loan_amount  max_loan_amount  min_loan_amount
# 0       8951.600000            14049              559
# 1      10289.300000            14971             3851
# 2       7894.850000            14399              811
# 3       7700.850000            14081             1607
# 4       7963.950000            13913             1212
# 5       7424.050000            14575              904
# 6       6633.263158            14802              851
# 7       6939.200000            13194              773
# 8       7173.555556            14767              667
# 9       7424.368421            14740              659

# %%
es = ft.EntitySet(id = 'clients')

# %%
et = ft.EntitySet(id = 'clients')

# %%
es = es.entity_from_dataframe(entity_id = 'clients', dataframe = clients, 
                              index = 'client_id', time_index = 'joined')

# %%
et =

# %%
es = es.entity_from_dataframe(entity_id = 'loans', dataframe = loans, 
                              variable_types = {'repaid': ft.variable_types.Categorical},
                              index = 'loan_id', 
                              time_index = 'loan_start')

# %%
es = es.entity_from_dataframe(entity_id = 'payments', 
                              dataframe = payments,
                              variable_types = {'missed': ft.variable_types.Categorical},
                              make_index = True,
                              index = 'payment_id',
                              time_index = 'payment_date')

# %%
es
# Out:
# Entityset: clients
#   Entities:
#     clients [Rows: 25, Columns: 6]
#     loans [Rows: 443, Columns: 8]
#     payments [Rows: 3456, Columns: 5]
#   Relationships:
#     No relationships

# %%
es['loans']
# Out:
# Entity: loans
#   Variables:
#     loan_id (dtype: index)
#     client_id (dtype: numeric)
#     loan_type (dtype: categorical)
#     loan_amount (dtype: numeric)
#     loan_start (dtype: datetime_time_index)
#     loan_end (dtype: datetime)
#     rate (dtype: numeric)
#     repaid (dtype: categorical)
#   Shape:
#     (Rows: 443, Columns: 8)

# %%
# Relationship between clients and previous loans
r_client_previous = ft.Relationship(es['clients']['client_id'],
                                    es['loans']['client_id'])

# Add the relationship to the entity set
es = es.add_relationship(r_client_previous)

# %%
r_payments = ft.Relationship(es['loans']['loan_id'],
                                      es['payments']['loan_id'])

# Add the relationship to the entity set
es = es.add_relationship(r_payments)

es
# Out:
# Entityset: clients
#   Entities:
#     clients [Rows: 25, Columns: 6]
#     loans [Rows: 443, Columns: 8]
#     payments [Rows: 3456, Columns: 5]
#   Relationships:
#     loans.client_id -> clients.client_id
#     payments.loan_id -> loans.loan_id

# %%
primitives = ft.list_primitives()
pd.options.display.max_colwidth = 100
primitives[primitives['type'] == 'aggregation'].head(10)
# Out:
#                name         type  \
# 0               sum  aggregation
# 1            median  aggregation
# 2               all  aggregation
# 3        num_unique  aggregation
# 4             count  aggregation
# 5  avg_time_between  aggregation
# 6               any  aggregation
# 7               max  aggregation
# 8     n_most_common  aggregation
# 9               min  aggregation
#
#                                                        description
# 0                   Sums elements of a numeric or boolean feature.
# 1  Finds the median value of any feature with well-ordered values.
# 2                                   Test if all values are 'True'.
# 3              Returns the number of unique categorical variables.
# 4                            Counts the number of non null values.
# 5            Computes the average time between consecutive events.
# 6                                     Test if any value is 'True'.
# 7           Finds the maximum non-null value of a numeric feature.
# 8       Finds the N most common elements in a categorical feature.
# 9           Finds the minimum non-null value of a numeric feature.

# %%
primitives[primitives['type'] == 'transform'].head(10)
# Out:
#                      name       type  \
# 20      modulo_by_feature  transform
# 21     add_numeric_scalar  transform
# 22  greater_than_equal_to  transform
# 23              cum_count  transform
# 24                   week  transform
# 25         modulo_numeric  transform
# 26       not_equal_scalar  transform
# 27           greater_than  transform
# 28              longitude  transform
# 29                 second  transform
#
#                                             description
# 20
# 21
# 22
# 23          Returns the cumulative count after grouping
# 24          Transform a Datetime feature into the week.
# 25
# 26
# 27
# 28  Returns the second value on the tuple base feature.
# 29        Transform a Datetime feature into the second.

# %%
# Create new features using specified primitives
features, feature_names = ft.dfs(entityset = es, target_entity = 'clients', 
                                 agg_primitives = ['mean', 'max', 'percent_true', 'last'],
                                 trans_primitives = ['year', 'month', 'divide_numeric'])

# %%
features
# Out:
#            income  credit_score  join_month  log_income  \
# client_id
# 25707      211422           621          10   12.261611
# 26326      227920           633           5   12.336750
# 26695      174532           680           8   12.069863
# 26945      214516           806          11   12.276140
# 29841       38354           523           8   10.554614
# 32726      235705           730           5   12.370336
# 32885       58955           642           5   10.984530
# 32961      230341           714           4   12.347316
# 35089      131176           771           3   11.784295
# 35214       95849           696           8   11.470529
# 38537      127183           643          10   11.753382
# 39384      191204           617           6   12.161096
# 39505      153873           610          10   11.943883
# 41472      152214           638          11   11.933043
# 41480      122607           585           3   11.716739
# 42320      229481           563           4   12.343576
# 44387      151903           781           7   11.930997
# 44601      156341           518          10   11.959795
# 46109      172677           527           4   12.059178
# 46180       43851           562          11   10.688553
# 46958      225709           644           7   12.327002
# 48177      190632           769           6   12.158100
# 49068      128813           603           2   11.766117
# 49545      104564           770          11   11.557555
# 49624       49036           800           8   10.800310
#
#            MEAN(loans.loan_amount)  MEAN(loans.rate)  MAX(loans.loan_amount)  \
# client_id
# 25707                  7963.950000          3.477000                   13913
# 26326                  7270.062500          2.517500                   13464
# 26695                  7824.722222          2.466111                   14865
# 26945                  7125.933333          2.855333                   14593
# 29841                  9813.000000          3.445000                   14837
# 32726                  6633.263158          3.058947                   14802
# 32885                  9920.400000          2.436000                   14162
# 32961                  7882.235294          3.930588                   14784
# 35089                  6939.200000          3.513500                   13194
# 35214                  7173.555556          3.108333                   14767
# 38537                  8986.352941          2.389412                   14804
# 39384                  7865.473684          3.538421                   14654
# 39505                  7424.050000          3.190500                   14575
# 41472                  7510.812500          3.981250                   13657
# 41480                  7894.850000          3.110500                   14399
# 42320                  7062.066667          2.457333                   13887
# 44387                  7387.733333          2.806667                   14900
# 44601                  6869.250000          4.151000                   14104
# 46109                  8951.600000          3.152500                   14049
# 46180                  7700.850000          3.502500                   14081
# 46958                  9378.384615          3.153846                   14942
# 48177                  7424.368421          3.938947                   14740
# 49068                  7617.888889          3.095556                   13910
# 49545                 10289.300000          2.684000                   14971
# 49624                  9174.533333          4.037333                   14679
#
#            MAX(loans.rate) LAST(loans.loan_type)  LAST(loans.loan_amount)  \
# client_id
# 25707                 9.44                  home                     2203
# 26326                 6.73                credit                     5275
# 26695                 6.51                 other                    13918
# 26945                 5.65                  cash                     9249
# 29841                 6.76                  home                     7223
# 32726                 9.10                 other                     5325
# 32885                 9.11                 other                    11886
# 32961                 9.14                  cash                     1693
# 35089                 7.63                 other                      773
# 35214                 8.44                  home                     9389
# 38537                 8.01                  cash                     8797
# 39384                 9.23                 other                    14654
# 39505                 9.91                  cash                     9600
# 41472                 9.82                  cash                    10122
# 41480                10.49                  home                    11154
# 42320                 6.74                  home                     8090
# 44387                 5.97                credit                     7279
# 44601                 9.22                 other                     6129
# 46109                 9.48                 other                    10853
# 46180                 9.26                 other                     3834
# 46958                 6.17                credit                     8308
# 48177                10.89                credit                      659
# 49068                 6.78                 other                    10082
# 49545                 6.52                  home                     7061
# 49624                12.62                  cash                     8621
#
#                              ...                      \
# client_id                    ...
# 25707                        ...
# 26326                        ...
# 26695                        ...
# 26945                        ...
# 29841                        ...
# 32726                        ...
# 32885                        ...
# 32961                        ...
# 35089                        ...
# 35214                        ...
# 38537                        ...
# 39384                        ...
# 39505                        ...
# 41472                        ...
# 41480                        ...
# 42320                        ...
# 44387                        ...
# 44601                        ...
# 46109                        ...
# 46180                        ...
# 46958                        ...
# 48177                        ...
# 49068                        ...
# 49545                        ...
# 49624                        ...
#
#            MEAN(loans.loan_amount) / LAST(loans.rate)  \
# client_id
# 25707                                     1076.209459
# 26326                                     5013.836207
# 26695                                     8694.135802
# 26945                                     2491.585082
# 29841                                     1927.897839
# 32726                                     2343.909243
# 32885                                     1088.957190
# 32961                                     5398.791297
# 35089                                      909.462647
# 35214                                     5123.968254
# 38537                                    14041.176471
# 39384                                     3480.298090
# 39505                                    29696.200000
# 41472                                     7292.050971
# 41480                                     1218.341049
# 42320                                     2220.775681
# 44387                                     1801.886179
# 44601                                     2488.858696
# 46109                                     3174.326241
# 46180                                     5580.326087
# 46958                                    29307.451923
# 48177                                     4884.452909
# 49068                                    12091.887125
# 49545                                     2432.458629
# 49624                                     2885.073375
#
#            MAX(payments.payment_amount) / income  \
# client_id
# 25707                                   0.012790
# 26326                                   0.011662
# 26695                                   0.016799
# 26945                                   0.012903
# 29841                                   0.075559
# 32726                                   0.011434
# 32885                                   0.041082
# 32961                                   0.012117
# 35089                                   0.019539
# 35214                                   0.029985
# 38537                                   0.022715
# 39384                                   0.014759
# 39505                                   0.017963
# 41472                                   0.016004
# 41480                                   0.022177
# 42320                                   0.012066
# 44387                                   0.019190
# 44601                                   0.017008
# 46109                                   0.015839
# 46180                                   0.060660
# 46958                                   0.013229
# 48177                                   0.014289
# 49068                                   0.021256
# 49545                                   0.027476
# 49624                                   0.058447
#
#            LAST(loans.rate) / MEAN(loans.loan_amount)  \
# client_id
# 25707                                        0.000929
# 26326                                        0.000199
# 26695                                        0.000115
# 26945                                        0.000401
# 29841                                        0.000519
# 32726                                        0.000427
# 32885                                        0.000918
# 32961                                        0.000185
# 35089                                        0.001100
# 35214                                        0.000195
# 38537                                        0.000071
# 39384                                        0.000287
# 39505                                        0.000034
# 41472                                        0.000137
# 41480                                        0.000821
# 42320                                        0.000450
# 44387                                        0.000555
# 44601                                        0.000402
# 46109                                        0.000315
# 46180                                        0.000179
# 46958                                        0.000034
# 48177                                        0.000205
# 49068                                        0.000083
# 49545                                        0.000411
# 49624                                        0.000347
#
#            LAST(payments.payment_amount) / credit_score  \
# client_id
# 25707                                          0.388084
# 26326                                          1.472354
# 26695                                          3.064706
# 26945                                          1.981390
# 29841                                          1.529637
# 32726                                          1.387671
# 32885                                          2.973520
# 32961                                          0.312325
# 35089                                          0.137484
# 35214                                          2.320402
# 38537                                          2.511664
# 39384                                          3.314425
# 39505                                          1.757377
# 41472                                          2.277429
# 41480                                          3.615385
# 42320                                          1.921847
# 44387                                          0.942382
# 44601                                          1.951737
# 46109                                          3.466793
# 46180                                          1.240214
# 46958                                          2.253106
# 48177                                          0.149545
# 49068                                          2.373134
# 49545                                          1.161039
# 49624                                          1.711250
#
#            credit_score / MAX(payments.payment_amount)  \
# client_id
# 25707                                         0.229660
# 26326                                         0.238149
# 26695                                         0.231924
# 26945                                         0.291185
# 29841                                         0.180469
# 32726                                         0.270872
# 32885                                         0.265070
# 32961                                         0.255822
# 35089                                         0.300819
# 35214                                         0.242171
# 38537                                         0.222568
# 39384                                         0.218639
# 39505                                         0.220695
# 41472                                         0.261905
# 41480                                         0.215153
# 42320                                         0.203322
# 44387                                         0.267925
# 44601                                         0.194810
# 46109                                         0.192687
# 46180                                         0.211278
# 46958                                         0.215673
# 48177                                         0.282305
# 49068                                         0.220234
# 49545                                         0.268013
# 49624                                         0.279135
#
#            credit_score / MEAN(loans.rate)  \
# client_id
# 25707                           178.602243
# 26326                           251.439921
# 26695                           275.737779
# 26945                           282.278777
# 29841                           151.814224
# 32726                           238.644184
# 32885                           263.546798
# 32961                           181.652200
# 35089                           219.439306
# 35214                           223.914209
# 38537                           269.103890
# 39384                           174.371560
# 39505                           191.192603
# 41472                           160.251177
# 41480                           188.072657
# 42320                           229.110147
# 44387                           278.266033
# 44601                           124.789207
# 46109                           167.168914
# 46180                           160.456817
# 46958                           204.195122
# 48177                           195.229824
# 49068                           194.795406
# 49545                           286.885246
# 49624                           198.150594
#
#            MEAN(loans.rate) / MEAN(payments.payment_amount)  \
# client_id
# 25707                                              0.002950
# 26326                                              0.002158
# 26695                                              0.002042
# 26945                                              0.002574
# 29841                                              0.002393
# 32726                                              0.003239
# 32885                                              0.001744
# 32961                                              0.003783
# 35089                                              0.003209
# 35214                                              0.002886
# 38537                                              0.001782
# 39384                                              0.002964
# 39505                                              0.002746
# 41472                                              0.003526
# 41480                                              0.002495
# 42320                                              0.002406
# 44387                                              0.002658
# 44601                                              0.003816
# 46109                                              0.002292
# 46180                                              0.002952
# 46958                                              0.002342
# 48177                                              0.003283
# 49068                                              0.002570
# 49545                                              0.001812
# 49624                                              0.002845
#
#            MAX(loans.loan_amount) / log_income  \
# client_id
# 25707                              1134.679573
# 26326                              1091.373338
# 26695                              1231.579806
# 26945                              1188.728743
# 29841                              1405.735904
# 32726                              1196.572158
# 32885                              1289.267758
# 32961                              1197.345227
# 35089                              1119.625719
# 35214                              1287.386100
# 38537                              1259.552328
# 39384                              1204.990057
# 39505                              1220.289931
# 41472                              1144.469214
# 41480                              1228.925515
# 42320                              1125.038688
# 44387                              1248.847808
# 44601                              1179.284447
# 46109                              1165.004772
# 46180                              1317.390695
# 46958                              1212.135781
# 48177                              1212.360469
# 49068                              1182.208198
# 49545                              1295.343220
# 49624                              1359.127655
#
#            LAST(loans.loan_amount) / income  \
# client_id
# 25707                              0.010420
# 26326                              0.023144
# 26695                              0.079745
# 26945                              0.043116
# 29841                              0.188325
# 32726                              0.022592
# 32885                              0.201611
# 32961                              0.007350
# 35089                              0.005893
# 35214                              0.097956
# 38537                              0.069168
# 39384                              0.076641
# 39505                              0.062389
# 41472                              0.066498
# 41480                              0.090974
# 42320                              0.035253
# 44387                              0.047919
# 44601                              0.039203
# 46109                              0.062851
# 46180                              0.087432
# 46958                              0.036808
# 48177                              0.003457
# 49068                              0.078268
# 49545                              0.067528
# 49624                              0.175810
#
#            MAX(payments.payment_amount) / log_income
# client_id
# 25707                                     220.525664
# 26326                                     215.453828
# 26695                                     242.919071
# 26945                                     225.478048
# 29841                                     274.571858
# 32726                                     217.859881
# 32885                                     220.491916
# 32961                                     226.041026
# 35089                                     217.492854
# 35214                                     250.555133
# 38537                                     245.801586
# 39384                                     232.051449
# 39505                                     231.415531
# 41472                                     204.139050
# 41480                                     232.061148
# 42320                                     224.327222
# 44387                                     244.321568
# 44601                                     222.328229
# 46109                                     226.798210
# 46180                                     248.864374
# 46958                                     242.232462
# 48177                                     224.048163
# 49068                                     232.702088
# 49545                                     248.581997
# 49624                                     265.362753
#
# [25 rows x 197 columns]
